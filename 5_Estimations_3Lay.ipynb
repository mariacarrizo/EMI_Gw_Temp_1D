# %%
# %matplotlib widget

# %% [markdown]
# # The potential of the electromagnetic induction method to monitor temperature changes in the near-surface
#
# ## Maria Carrizo, Dieter Werthmüller, and Evert Slob
# Delft University of Technology, Faculty of Civil Engineering and Geosciences , Department of Applied Geophysics and Petrophysics, Delft, Netherlands (m.e.carrizomascarell@tudelft.nl)

# %%
import numpy as np
import matplotlib.pyplot as plt
from empymod import filters
import pygimli as pg
import matplotlib.tri as tri
from joblib import Parallel, delayed
import matplotlib
import copy
import sys
sys.path.insert(1, 'src')

# Load function that performs global search in lookup table
from EM1D import EMf_3Lay_HVP, GlobalSearch_3Lay, EMf_3Lay_Opt_HVP, ErrorSpace_3Lay
from Plots import PlotModelData, PlotErrorSpace_3Lay
from utils import rmse

# %% [markdown]
# ## EM Induction
#
# For the models data is simulated for an EMI device with the following characteristics
#   - Frequency: 9000 Hz
#   - Geometries: Horizontal coplanar (H) with offsets [2 m, 4 m, 8 m], Vertical coplanar (V) with offsets [2 m, 4 m, 8 m], and Perpendicular (P) with offsets [2.1 m, 4.1 m, 8.1 m]
#   - Data obtained: vector with the Quadrature (Q) and In-phase (IP) components of the measurements for the H, V and P coil orientations: $\mathbf{d} = [Q_{H2}, Q_{H4}, Q_{H8}, Q_{V2}, Q_{V4}, Q_{V8}, Q_{P2}, Q_{P4}, Q_{P8}, IP_{H2}, IP_{H4}, IP_{H8}, IP_{V2}, IP_{V4}, IP_{V8}, IP_{P2}, IP_{P4}, IP_{P8}]$

# %% [markdown]
# Assuming 3-layered EC models the model parameters would be a model $m$ vector:
#
# \begin{equation}
#     \mathbf{m} = [\sigma_1, \sigma_2, \sigma_3, h_1, h_2],
# \end{equation}
#
# where $\sigma_1$ is the EC of the first layer, $\sigma_2$ is the electrical conductivity of the second layer, $\sigma_3$ is the electrical conductivity of the third layer, $h_1$ is the thickness of the first layer and $h_2$ is the thickness of the second layer
#
# We use the method discussed in [Carrizo et. al., 2023](https://doi.org/10.3997/2214-4609.202320049) to generate Lookup tables and perform a global search to estimate a 3-layered model.
#
# The lookup table was generated using `1_LUTable3Lay.py` and stored in `Lookup_Tables/3Lay`. The global search will find the best data fit in the lookup table indicating the best fitting model.

# %%
# Settings for measurements simulations

# Define hankel filter
filt = filters.key_201_2012() 

# Define EMI instrument geometry
offsets = np.array([2, 4, 8]) # in meters
height = 0.10 # meters height from ground surface to center of coils
freq = 9000 # Frequency in Hz
# Lambda numbers
lambd = filt.base/offsets[:,np.newaxis]

# %%
# number of cores used to perform the global search
n_workers=8

# Load conductivities and layer thicknesses sampled
conds = np.load('../GSplusOpt/Synth-3Layers/data/conds.npy')
thicks = np.load('../GSplusOpt/Synth-3Layers/data/thicks.npy')
nsl = len(conds) # number of samples

# Load lookup table
LU_3Lay = np.load('../GSplusOpt/Synth-3Layers/data/LUTable_3Lay.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 10
#       7 nsl = len(conds) # number of samples
#       9 # Load lookup table
# ---> 10 LU_3Lay = np.load('../GSplusOpt/Synth-3Layers/data/LUTable_3Lay.npy')
#
# File ~/anaconda3/envs/pg-empy-emg3d/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../GSplusOpt/Synth-3Layers/data/LUTable_3Lay.npy'

# %%
# Generate a 2 layered model and simulate EMI measurements

sigma_1 = 10/1000 # S/m
sigma_2 = 30/1000 # S/m
sigma_3 = 350/1000 # S/m
h1 = 2 # m
h2 = 2.4

model_3Lay_true =  ([sigma_1, sigma_2, sigma_3, h1,  h2])
data_3Lay_true = EMf_3Lay_HVP(lambd, 
                              sigma_1, 
                              sigma_2,
                              sigma_3,
                              h1, 
                              h2,
                              height, offsets, freq, filt)

# %%
# Perform inversion with global search
model_3Lay_est = GlobalSearch_3Lay(LU_3Lay, data_3Lay_true, conds, thicks, nsl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Perform inversion with global search
# ----> 2 model_3Lay_est = GlobalSearch_3Lay(LU_3Lay, data_3Lay_true, conds, thicks, nsl)
#
# NameError: name 'LU_3Lay' is not defined

# %%
# Simulate measurements for the estimated model
data_3Lay_est = EMf_3Lay_HVP(lambd, 
                             sigma1 = model_3Lay_est[0],
                             sigma2 = model_3Lay_est[1],
                             sigma3 = model_3Lay_est[2],
                             h1 = model_3Lay_est[3],
                             h2 = model_3Lay_est[4],
                             height = height,
                             offsets = offsets,
                             freq = freq,
                             filt = filt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Simulate measurements for the estimated model
#       2 data_3Lay_est = EMf_3Lay_HVP(lambd,
# ----> 3                              sigma1 = model_3Lay_est[0],
#       4                              sigma2 = model_3Lay_est[1],
#       5                              sigma3 = model_3Lay_est[2],
#       6                              h1 = model_3Lay_est[3],
#       7                              h2 = model_3Lay_est[4],
#       8                              height = height,
#       9                              offsets = offsets,
#      10                              freq = freq,
#      11                              filt = filt)
#
# NameError: name 'model_3Lay_est' is not defined

# %%
# Plot the estimated model
    
dmax = -12
sigma_3Lay_true_plot = np.hstack((model_3Lay_true[:3], model_3Lay_true[2]))
depths_3Lay_true_plot = np.array([0, -h1, -h1-h2, dmax])

sigma_3Lay_est_plot = np.hstack((model_3Lay_est[:3], model_3Lay_est[2]))
depths_3Lay_est_plot = np.array([0, -model_3Lay_est[3], -model_3Lay_est[3]-model_3Lay_est[4], dmax])

fig, ax = plt.subplots(1,2)

PlotModelData(sigma_3Lay_true_plot, depths_3Lay_true_plot, data_3Lay_true, model_name='True', data_name='True',
             ax=ax, data_style='k')
PlotModelData(sigma_3Lay_est_plot, depths_3Lay_true_plot, data_3Lay_est, model_name='Estimated', 
              data_name='Estimated', ax=ax, model_style=':r', data_style='r')
ax[1].text(1, 75, '$\chi^2$ = '+ "{:1.2f}".format(rmse(data_3Lay_true, data_3Lay_est)))

plt.savefig('figures/3Lay_Model.eps', format='eps')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       4 sigma_3Lay_true_plot = np.hstack((model_3Lay_true[:3], model_3Lay_true[2]))
#       5 depths_3Lay_true_plot = np.array([0, -h1, -h1-h2, dmax])
# ----> 7 sigma_3Lay_est_plot = np.hstack((model_3Lay_est[:3], model_3Lay_est[2]))
#       8 depths_3Lay_est_plot = np.array([0, -model_3Lay_est[3], -model_3Lay_est[3]-model_3Lay_est[4], dmax])
#      10 fig, ax = plt.subplots(1,2)
#
# NameError: name 'model_3Lay_est' is not defined

# %%
def NoiseAnalysis_3Lay(data_true, noise=0.1, test_it=100):
    
    data_noise = []
    for i in range(test_it):
        data_noise.append(data_true* (1 +np.random.normal(size=len(data_true))*noise))

    models = Parallel(n_jobs=n_workers,verbose=0)(delayed(GlobalSearch_3Lay)(LU_3Lay, 
                    data, conds, thicks, nsl) for data in data_noise)
    return models
        
models_noise = NoiseAnalysis_3Lay(data_3Lay_true)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~/anaconda3/envs/pg-empy-emg3d/lib/python3.11/site-packages/joblib/parallel.py:1423, in Parallel.dispatch_one_batch(self, iterator)
#    1422 try:
# -> 1423     tasks = self._ready_batches.get(block=False)
#    1424 except queue.Empty:
#    1425     # slice the iterator n_jobs * batchsize items at a time. If the
#    1426     # slice returns less than that, then the current batchsize puts
#    (...)
#    1429     # accordingly to distribute evenly the last items between all
#    1430     # workers.
#
# File ~/anaconda3/envs/pg-empy-emg3d/lib/python3.11/queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       7     models = Parallel(n_jobs=n_workers,verbose=0)(delayed(GlobalSearch_3Lay)(LU_3Lay,
#       8                     data, conds, thicks, nsl) for data in data_noise)
#       9     return models
# ---> 11 models_noise = NoiseAnalysis_3Lay(data_3Lay_true)
#
# Cell In[15], line 7, in NoiseAnalysis_3Lay(data_true, noise, test_it)
#       4 for i in range(test_it):
#       5     data_noise.append(data_true* (1 +np.random.normal(size=len(data_true))*noise))
# ----> 7 models = Parallel(n_jobs=n_workers,verbose=0)(delayed(GlobalSearch_3Lay)(LU_3Lay,
#       8                 data, conds, thicks, nsl) for data in data_noise)
#       9 return models
#
# File ~/anaconda3/envs/pg-empy-emg3d/lib/python3.11/site-packages/joblib/parallel.py:1950, in Parallel.__call__(self, iterable)
#    1944 self._call_ref = weakref.ref(output)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
# -> 1950 next(output)
#    1952 return output if self.return_generator else list(output)
#
# File ~/anaconda3/envs/pg-empy-emg3d/lib/python3.11/site-packages/joblib/parallel.py:1588, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1586 detach_generator_exit = False
#    1587 try:
# -> 1588     self._start(iterator, pre_dispatch)
#    1589     # first yield returns None, for internal use only. This ensures
#    1590     # that we enter the try/except block and start dispatching the
#    1591     # tasks.
#    1592     yield
#
# File ~/anaconda3/envs/pg-empy-emg3d/lib/python3.11/site-packages/joblib/parallel.py:1571, in Parallel._start(self, iterator, pre_dispatch)
#    1562 def _start(self, iterator, pre_dispatch):
#    1563     # Only set self._iterating to True if at least a batch
#    1564     # was dispatched. In particular this covers the edge
#    (...)
#    1568     # was very quick and its callback already dispatched all the
#    1569     # remaining jobs.
#    1570     self._iterating = False
# -> 1571     if self.dispatch_one_batch(iterator):
#    1572         self._iterating = self._original_iterator is not None
#    1574     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/envs/pg-empy-emg3d/lib/python3.11/site-packages/joblib/parallel.py:1434, in Parallel.dispatch_one_batch(self, iterator)
#    1431 n_jobs = self._cached_effective_n_jobs
#    1432 big_batch_size = batch_size * n_jobs
# -> 1434 islice = list(itertools.islice(iterator, big_batch_size))
#    1435 if len(islice) == 0:
#    1436     return False
#
# Cell In[15], line 7, in <genexpr>(.0)
#       4 for i in range(test_it):
#       5     data_noise.append(data_true* (1 +np.random.normal(size=len(data_true))*noise))
# ----> 7 models = Parallel(n_jobs=n_workers,verbose=0)(delayed(GlobalSearch_3Lay)(LU_3Lay,
#       8                 data, conds, thicks, nsl) for data in data_noise)
#       9 return models
#
# NameError: name 'LU_3Lay' is not defined

# %%
# Plot the models

fig, ax = plt.subplots()

for m in range(len(models_noise)):
    mod = models_noise[m]
    sigma_3Lay_plot = np.hstack((mod[:3], mod[2]))
    depths_3Lay_plot = np.array([0, -mod[3], -mod[3]-mod[4], dmax])
    PlotModel(sigma_3Lay_plot, depths_3Lay_plot, ax=ax, model_style='paleturquoise')
PlotModel(sigma_3Lay_true_plot, depths_3Lay_true_plot, model_name='True', ax=ax)

plt.title('10 % Noise in measurements') 
plt.savefig('figures/3Lay_Noise.eps', format='eps')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 # Plot the models
#       3 fig, ax = plt.subplots()
# ----> 5 for m in range(len(models_noise)):
#       6     mod = models_noise[m]
#       7     sigma_3Lay_plot = np.hstack((mod[:3], mod[2]))
#
# NameError: name 'models_noise' is not defined
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Gradient descent inversion
#
# It's also possible to obtain the estimated model through a gradient descent inversion by minimising the misfit of the following equation iteratively, given an initial model.
#
# \begin{equation}
#    \Phi = \lVert \boldsymbol{W}_d (\mathcal{F}(\boldsymbol{m}) - \boldsymbol{d}) \rVert_2^2 + \alpha \rVert \boldsymbol{W}_m (\boldsymbol{m} - \boldsymbol{m}_0) \lVert_2^2 ,
# \end{equation}

# %%
# Initialize the forward modelling class 
EMf = EMf_3Lay_Opt_HVP(lambd, height, offsets, freq, filt)

# Define inversion framework from pygimli
invEM = pg.Inversion()
invEM.setForwardOperator(EMf) # set forward operator

transModel = pg.trans.TransLogLU(0.01,3) 
invEM.modelTrans = transModel

# Relative error array
error = 1e-3 # relative error
relativeError = np.ones_like(data_3Lay_true) * error

# Start inversion
model_3Lay_est_gd = invEM.run(data_3Lay_true, relativeError, verbose=False)

# Data from estimated model
data_3Lay_est_gd = EMf_3Lay_HVP(lambd, 
                             sigma1 = model_3Lay_est_gd[0],
                             sigma2 = model_3Lay_est_gd[1],
                             sigma3 = model_3Lay_est_gd[2],
                             h1 = model_3Lay_est_gd[3],
                             h2 = model_3Lay_est_gd[4],
                             height = height,
                             offsets = offsets,
                             freq = freq,
                             filt = filt)
# Out:
# 17/04/24 - 09:46:59 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000

# %%
sigma_3Lay_est_gd_plot = np.hstack((model_3Lay_est_gd[:3], model_3Lay_est_gd[2]))
depths_3Lay_est_gd_plot = np.array([0, -model_3Lay_est_gd[3], -model_3Lay_est_gd[3] -model_3Lay_est_gd[4],dmax])

fig, ax = plt.subplots(1,2)

PlotModelData(sigma_3Lay_true_plot, depths_3Lay_true_plot, data_3Lay_true, model_name='True', data_name='True',
             ax=ax, data_style='k')
PlotModelData(sigma_3Lay_est_plot, depths_3Lay_est_plot, data_3Lay_est, model_name='Estimated GS', 
              data_name='Estimated GS', ax=ax, model_style=':r', data_style='r')
PlotModelData(sigma_3Lay_est_gd_plot, depths_3Lay_est_gd_plot, data_3Lay_est_gd, model_name='Estimated GD', 
              data_name='Estimated GD', ax=ax, model_style=':g', data_style='g')

ax[1].text(3, 75, '$\chi^2$ GS = '+ "{:1.2f}".format(rmse(data_3Lay_true, data_3Lay_est)), fontsize='small')
ax[1].text(3, 70, '$\chi^2$ GD = '+ "{:1.2f}".format(rmse(data_3Lay_true, data_3Lay_est_gd)), fontsize='small')

plt.savefig('figures/3Lay_Model_GS_GD.eps', format='eps')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       2 depths_3Lay_est_gd_plot = np.array([0, -model_3Lay_est_gd[3], -model_3Lay_est_gd[3] -model_3Lay_est_gd[4],dmax])
#       4 fig, ax = plt.subplots(1,2)
# ----> 6 PlotModelData(sigma_3Lay_true_plot, depths_3Lay_true_plot, data_3Lay_true, model_name='True', data_name='True',
#       7              ax=ax, data_style='k')
#       8 PlotModelData(sigma_3Lay_est_plot, depths_3Lay_est_plot, data_3Lay_est, model_name='Estimated GS',
#       9               data_name='Estimated GS', ax=ax, model_style=':r', data_style='r')
#      10 PlotModelData(sigma_3Lay_est_gd_plot, depths_3Lay_est_gd_plot, data_3Lay_est_gd, model_name='Estimated GD',
#      11               data_name='Estimated GD', ax=ax, model_style=':g', data_style='g')
#
# NameError: name 'PlotModelData' is not defined
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def NoiseAnalysis_3Lay_GD(data_true, noise=0.1, test_it=100):
    
    models = []
    for i in range(test_it):
        data_noise = data_true* (1 +np.random.normal(size=len(data_true))*noise)
        
        # Initialize the forward modelling class 
        EMf = EMf_3Lay_Opt_HVP(lambd, height, offsets, freq, filt)

        # Define inversion framework from pygimli
        invEM = pg.Inversion()
        invEM.setForwardOperator(EMf) # set forward operator

        transModel = pg.trans.TransLogLU(0.01,3) 
        invEM.modelTrans = transModel

        # Relative error array
        error = 1e-3 # relative error
        relativeError = np.ones_like(data_true[0]) * error

        # Start inversion
        models.append(invEM.run(data_noise, relativeError, verbose=False))

    return models
        
models_noise = NoiseAnalysis_3Lay_GD(data_3Lay_true)
# Out:
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:36 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:37 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:38 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000
# 16/04/24 - 01:42:39 - pyGIMLi - INFO - Created startmodel from forward operator: 5, min/max=0.050000/2.000000

# %%
fig, ax = plt.subplots()

for m in range(len(models_noise)):
    mod = models_noise[m]
    sigma_3Lay_plot = np.hstack((mod[:3], mod[2]))
    depths_3Lay_plot = np.array([0, -mod[3], -mod[3]-mod[4], dmax])
    PlotModel(sigma_3Lay_plot, depths_3Lay_plot, ax=ax, model_style='paleturquoise')
PlotModel(sigma_3Lay_true_plot, depths_3Lay_true_plot, model_name='True', ax=ax)

plt.title('10 % Noise in measurements') 
plt.tight_layout()
plt.savefig('figures/3Lay_Noise_GD.eps', format='eps')
# Out:
# 16/04/24 - 01:42:49 - matplotlib.backends.backend_ps - WARNING - The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Analysis error space

# %%
# search the error space and output models with error < 0.1
   
models_err, err = ErrorSpace_3Lay(model_3Lay_est, data_3Lay_true, conds, thicks)

# %%
models_err = np.array(models_err)
error = np.array(error)

# %%
PlotErrorSpace_3Lay(model_3Lay_true, model_3Lay_est, err, models_err)

plt.savefig('figures/3Lay_ErrorSpace.eps', format='eps')
# Out:
# /tmp/ipykernel_849732/1676789217.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   my_cmap = copy.copy(matplotlib.cm.get_cmap("RdBu_r")) # copy the default cmap
# 16/04/24 - 01:43:29 - matplotlib.backends.backend_ps - WARNING - The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
